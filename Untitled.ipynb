# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model as lr
import numpy as np

# %%
data=pd.read_csv("sleep.csv",sep=',')
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#pretraitement des données
data = data.drop('Person ID',axis=1)

# %%
#modification des données de la colonne Sleep Disorder
for i in range(374):
    if data['Sleep Disorder'].iloc[i] == 'None':
        data['Sleep Disorder'].iloc[i] = 0.001
    elif data['Sleep Disorder'].iloc[i] == 'Sleep Apnea':
        data['Sleep Disorder'].iloc[i] = 0.599;
    elif data['Sleep Disorder'].iloc[i] == 'Insomnia':
        data['Sleep Disorder'].iloc[i] = 0.999
# Out:
# C:\Users\HPPAVI~1\AppData\Local\Temp/ipykernel_4756/1573731228.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sleep Disorder'].iloc[i] = 0.001
# C:\Users\HPPAVI~1\AppData\Local\Temp/ipykernel_4756/1573731228.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sleep Disorder'].iloc[i] = 0.599;
# C:\Users\HPPAVI~1\AppData\Local\Temp/ipykernel_4756/1573731228.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#modification des données de la colonne Gender
for i in range(374):
    if data['Gender'].iloc[i] == 'Female':
        data['Gender'].iloc[i] = 0.999
   # else :
    #      data['Gender'].iloc[i] == 0.999
# Out:
# C:\Users\HPPAVI~1\AppData\Local\Temp/ipykernel_4756/740792095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender'].iloc[i] = 0.999

# %%
data
# Out:
#     Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0    0.001   27             6.1                 6                       42
# 1    0.001   28             6.2                 6                       60
# 2    0.001   28             6.2                 6                       60
# 3    0.001   28             5.9                 4                       30
# 4    0.001   28             5.9                 4                       30
# ..     ...  ...             ...               ...                      ...
# 369  0.999   59             8.1                 9                       75
# 370  0.999   59             8.0                 9                       75
# 371  0.999   59             8.1                 9                       75
# 372  0.999   59             8.1                 9                       75
# 373  0.999   59             8.1                 9                       75
#
#      Stress Level  Heart Rate  Daily Steps Sleep Disorder
# ...

# %%
#suppression des autres colonnes inutiles
data
# Out:
#     Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0    0.001   27             6.1                 6                       42
# 1    0.001   28             6.2                 6                       60
# 2    0.001   28             6.2                 6                       60
# 3    0.001   28             5.9                 4                       30
# 4    0.001   28             5.9                 4                       30
# ..     ...  ...             ...               ...                      ...
# 369  0.999   59             8.1                 9                       75
# 370  0.999   59             8.0                 9                       75
# 371  0.999   59             8.1                 9                       75
# 372  0.999   59             8.1                 9                       75
# 373  0.999   59             8.1                 9                       75
#
#      Stress Level  Heart Rate  Daily Steps Sleep Disorder
# ...

# %%
#suppression des autres colonnes inutiles
data
# Out:
#     Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0    0.001   27             6.1                 6                       42
# 1    0.001   28             6.2                 6                       60
# 2    0.001   28             6.2                 6                       60
# 3    0.001   28             5.9                 4                       30
# 4    0.001   28             5.9                 4                       30
# ..     ...  ...             ...               ...                      ...
# 369  0.999   59             8.1                 9                       75
# 370  0.999   59             8.0                 9                       75
# 371  0.999   59             8.1                 9                       75
# 372  0.999   59             8.1                 9                       75
# 373  0.999   59             8.1                 9                       75
#
#      Stress Level  Heart Rate  Daily Steps Sleep Disorder
# ...

# %%
data.iloc[250]
# Out:
# Gender                     0.999
# Age                           45
# Sleep Duration               6.8
# Quality of Sleep               7
# Physical Activity Level       30
# Stress Level                   6
# Heart Rate                    65
# Daily Steps                 6000
# Sleep Disorder             0.999
# Name: 250, dtype: object

# %%
#preparation des données 
X_train = data.iloc[:,:8]
Y_train = data.iloc[:,8:9]
Y_train
# Out:
#     Sleep Disorder
# 0            0.001
# 1            0.001
# 2            0.001
# 3            0.599
# 4            0.599
# ..             ...
# 369          0.599
# 370          0.599
# 371          0.599
# 372          0.599
# 373          0.599
#
# [374 rows x 1 columns]

# %%
#entrainement du modèle 
model = lr.LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
coef = model.coef_
init = model.intercept_

# %%
coef
# Out:
# array([[-1.66601375e-01,  3.51883059e-02, -1.60554083e-01,
#         -4.04169960e-01,  3.69681057e-03, -1.92858728e-01,
#         -3.42283624e-03, -3.95407597e-05]])

# %%
init
# Out:
# array([4.35942545])

# %%
#données test
x = np.ones(8)

for i in range(8):
    x[i] = X_train.iloc[0,i]
x.reshape(8,1)
# Out:
# array([[1.0e-03],
#        [2.7e+01],
#        [6.1e+00],
#        [6.0e+00],
#        [4.2e+01],
#        [6.0e+00],
#        [7.7e+01],
#        [4.2e+03]])

# %%
y = init + coef.dot(x)
y
# Out:
# array([0.47342753])

# %%
data
# Out:
#     Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0    0.001   27             6.1                 6                       42
# 1    0.001   28             6.2                 6                       60
# 2    0.001   28             6.2                 6                       60
# 3    0.001   28             5.9                 4                       30
# 4    0.001   28             5.9                 4                       30
# ..     ...  ...             ...               ...                      ...
# 369  0.999   59             8.1                 9                       75
# 370  0.999   59             8.0                 9                       75
# 371  0.999   59             8.1                 9                       75
# 372  0.999   59             8.1                 9                       75
# 373  0.999   59             8.1                 9                       75
#
#      Stress Level  Heart Rate  Daily Steps Sleep Disorder
# ...
